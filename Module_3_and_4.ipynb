# %% [markdown]
# <a href="https://colab.research.google.com/github/cromcruach52/Pandas-Numpy-References/blob/main/Module_3_and_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Loading

# %%
import pandas as pd

# %%
df = pd.read_csv('WineQT.csv')

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %% [markdown]
# # Data Exploration

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
print(df.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB
# None

# %% [markdown]
# # CHecking and Handling Missing Data

# %%
df.shape
# Out:
# (1143, 13)

# %%
df_cleaned = df.dropna()

# %%
df_cleaned.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            6.7              0.58         0.08             1.8      0.097
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
df_inputed = df.fillna(df.mean)

# %%
df_inputed.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            6.7              0.58         0.08             1.8      0.097
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %% [markdown]
# fillna and dropna are just for cleaning data

# %% [markdown]
# # Filtering and Selecting Data

# %%
selected_col = df[['fixed acidity', 'volatile acidity']]

# %%
selected_col
# Out:
#       fixed acidity  volatile acidity
# 0               7.4             0.700
# 1               7.8             0.880
# 2               7.8             0.760
# 3              11.2             0.280
# 4               7.4             0.700
# ...             ...               ...
# 1138            6.3             0.510
# 1139            6.8             0.620
# 1140            6.2             0.600
# 1141            5.9             0.550
# 1142            5.9             0.645
#
# [1143 rows x 2 columns]

# %%
filter_col = df[df['quality'] > 5]

# %%
filter_col
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 3              11.2              0.28         0.56             1.9      0.075
# 7               7.3              0.65         0.00             1.2      0.065
# 8               7.8              0.58         0.02             2.0      0.073
# 12              8.5              0.28         0.56             1.8      0.092
# 13              7.9              0.32         0.51             1.8      0.341
# ...             ...               ...          ...             ...        ...
# 1136            6.3              0.55         0.15             1.8      0.077
# 1137            5.4              0.74         0.09             1.7      0.089
# 1138            6.3              0.51         0.13             2.3      0.076
# 1139            6.8              0.62         0.08             1.9      0.068
# 1141            5.9              0.55         0.10             2.2      0.062
#
# ...

# %%
filter_col2 = df[df['quality'] > 3]

# %%
filter_col2
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
filter_col3 = df[df['quality'] < 5]

# %%
filter_col3
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 29              8.8             0.610         0.30             2.8      0.088
# 32              4.6             0.520         0.15             2.1      0.054
# 50              8.3             0.675         0.26             2.1      0.084
# 54              8.3             0.625         0.20             1.5      0.080
# 66              5.0             1.020         0.04             1.4      0.045
# 103             9.2             0.520         1.00             3.4      0.610
# 112             7.6             0.680         0.02             1.3      0.072
# 118             7.3             0.550         0.03             1.6      0.072
# 120             7.9             0.885         0.03             1.8      0.058
# 142             6.9             1.090         0.06             2.1      0.061
# 185             7.0             0.975         0.04             2.0      0.087
# ...

# %% [markdown]
# # Data Transformation

# %% [markdown]
# # Merging and Concatenating DartaFrames

# %%
df3 = pd.DataFrame({('ID'):[1, 2], 'Name':['Jiro', 'Clark']})

# %%
df4 = pd.DataFrame({('ID'):[3, 4], 'Name':['Jester', 'Hans']})

# %%
df3
# Out:
#    ID   Name
# 0   1  Alice
# 1   2    Bob

# %%
df4
# Out:
#    ID    Name
# 0   3  Jester
# 1   4    Hans

# %%
df_c = pd.concat([df3, df4], axis = 0)

# %%
df_c
# Out:
#    ID    Name
# 0   1   Alice
# 1   2     Bob
# 0   3  Jester
# 1   4    Hans

# %%
df_m = pd.merge(df3, df4, on = 'ID')

# %%
df_m
# Out:
# Empty DataFrame
# Columns: [ID, Name_x, Name_y]
# Index: []

# %% [markdown]
# # Handling Duplicates

# %% [markdown]
# # Exporting Data

# %%
filter_col.to_csv('cleaned.csv', index = False)

# %%
filter_col2.to_csv('cleaned2.csv', index = False)

# %% [markdown]
# # Module 4 NumPy

# %%
# Meaning of Py, it provides support for large, multi0dimesional arrays and matrices, along with a collection of high-levelmathematical functions to operate on these arrays.

# %%
import numpy as np

# %%
matrix = np.array([[1,2,3],[4,5,6]])

# %%
print(matrix[1,2])
# Out:
# 6

# %%
print(matrix)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
result = matrix * 2

# %%
print(result)
# Out:
# [[ 2  4  6]
#  [ 8 10 12]]

# %% [markdown]
# # Broadcasting

# %%
result2 = matrix + 10

# %%
print(result2)
# Out:
# [[11 12 13]
#  [14 15 16]]

# %% [markdown]
# # Universal Functions

# %%
arr1 = np.array([1, 2, 3, 4, 5, 6])

# %%
squared = np.square(arr1)

# %%
squared
# Out:
# array([ 1,  4,  9, 16, 25, 36])

# %% [markdown]
# # Vectorization

# %% [markdown]
# # Efficient Memory Management

# %% [markdown]
# # Linear Algebra Operations
